# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Pie Chart

# %%
value = [1400,600, 300, 410, 250]
label = ["Home Rent", "Food", "Internet", "car", "others"]

# %%
plt.pie(value, labels= label)
# Out:
# ([<matplotlib.patches.Wedge at 0x29f0399a730>,
# ...
#  [Text(0.09328656407206024, 1.0960372333838069, 'Home Rent'),
#   Text(-0.9822184890776084, -0.4952240298229684, 'Food'),
#   Text(-0.16284704617934698, -1.0878790555712807, 'Internet'),
#   Text(0.6256100334857941, -0.9047718419590123, 'car'),
#   Text(1.0615045230766318, -0.28845822485734873, 'others')])

# %%
plt.pie(value, labels= label, radius=1.5, autopct = "%1.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x29f09693f70>,
# ...
#  [Text(0.13992984610809037, 1.6440558500757103, 'Home Rent'),
#   Text(-1.4733277336164126, -0.7428360447344526, 'Food'),
#   Text(-0.2442705692690205, -1.6318185833569212, 'Internet'),
#   Text(0.9384150502286911, -1.3571577629385183, 'car'),
#   Text(1.5922567846149476, -0.43268733728602315, 'others')],
#  [Text(0.07632537060441291, 0.8967577364049328, '47.30%'),
#   Text(-0.8036333092453158, -0.40518329712788315, '20.27%'),
#   Text(-0.1332384923285566, -0.8900828636492296, '10.14%'),
#   Text(0.511862754670195, -0.7402678706937371, '13.85%'),
#   Text(0.8685037006990621, -0.2360112748832853, '8.45%')])

# %% [markdown]
# ### Histogram

# %%
blood_sugar = [113, 85, 90, 150, 149, 93, 115, 80, 77, 82, 129]

# %%
plt.hist(blood_sugar)
# Out:
# (array([3., 2., 1., 0., 1., 1., 0., 1., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, rwidth=.8)
# Out:
# (array([3., 2., 1., 0., 1., 1., 0., 1., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar,density= True, cumulative= True, rwidth=.8, bins=4)
# Out:
# (array([0.54545455, 0.63636364, 0.81818182, 1.        ]),
#  array([ 77.  ,  95.25, 113.5 , 131.75, 150.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist?
# Out:
# Signature:
# plt.hist(
#     x,
#     bins=None,
#     range=None,
#     density=False,
#     weights=None,
#     cumulative=False,
#     bottom=None,
#     histtype='bar',
#     align='mid',
#     orientation='vertical',
#     rwidth=None,
#     log=False,
#     color=None,
#     label=None,
#     stacked=False,
#     *,
#     data=None,
#     **kwargs,
# )
# Docstring:
# Plot a histogram.
#
# Compute and draw the histogram of *x*.  The return value is a tuple
# (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
# *patches1*, ...]) if the input contains multiple data.  See the
# documentation of the *weights* parameter to draw a histogram of
# already-binned data.
#
# Multiple data can be provided via *x* as a list of datasets
# of potentially different length ([*x0*, *x1*, ...]), or as
# a 2D ndarray in which each column is a dataset.  Note that
# the ndarray form is transposed relative to the list form.
#
# Masked arrays are not supported.
#
# ...

# %%
plt.xlabel("Sugar Level")
plt.ylabel("No. of patients")
plt.title("Blood Sugar Level")
plt.hist(blood_sugar, rwidth=.8, bins=[80, 100])
plt.hist(blood_sugar, rwidth=.8, bins=[90, 125])
plt.hist(blood_sugar, rwidth=.8, bins=[125, 150])
# Out:
# (array([3.]), array([125, 150]), <BarContainer object of 1 artists>)

# %%
df.plot(x = "ZN", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "INDUS", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "RM", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "AGE", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "DIS", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "RAD", y= "Price", marker= ".", linestyle = "", markersize = 10)
df.plot(x = "PTRATIO", y= "Price", marker= ".", linestyle = "", markersize = 10)
